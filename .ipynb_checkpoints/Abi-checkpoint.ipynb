# %%
## Import the packages
import numpy as np
from scipy import stats 
import pandas as pd
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('avocado.csv')
df_original= df.copy()
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
# Unnamed: 0      18249 non-null int64
# Date            18249 non-null object
# AveragePrice    18249 non-null float64
# Total Volume    18249 non-null float64
# 4046            18249 non-null float64
# 4225            18249 non-null float64
# 4770            18249 non-null float64
# Total Bags      18249 non-null float64
# Small Bags      18249 non-null float64
# Large Bags      18249 non-null float64
# XLarge Bags     18249 non-null float64
# type            18249 non-null object
# year            18249 non-null int64
# region          18249 non-null object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
for column in list(df.columns):
   print(column,end= '\n')
# Out:
# Unnamed: 0
# Date
# AveragePrice
# Total Volume
# 4046
# 4225
# 4770
# Total Bags
# Small Bags
# Large Bags
# XLarge Bags
# type
# year
# region

# %%
df.isna().any()
# Out:
# Unnamed: 0      False
# Date            False
# AveragePrice    False
# Total Volume    False
# 4046            False
# 4225            False
# 4770            False
# Total Bags      False
# Small Bags      False
# Large Bags      False
# XLarge Bags     False
# type            False
# year            False
# region          False
# dtype: bool

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
df.isnull().any()
# Out:
# Unnamed: 0      False
# Date            False
# AveragePrice    False
# Total Volume    False
# 4046            False
# 4225            False
# 4770            False
# Total Bags      False
# Small Bags      False
# Large Bags      False
# XLarge Bags     False
# type            False
# year            False
# region          False
# dtype: bool

# %%
df.drop('Unnamed: 0',axis=1,inplace = True)
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %% [markdown]
# Hypothesis to respond
#
# - H1: Organic is more expensive than conventional
#
# - H2: People prefer to buy small bags of avocados
#
# - H3: The sale of  organic avocados has increased during the years

# %%
df['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df.type.unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
df_unclean = df.copy()
df = df[~df.region.isin(['TotalUS', 'West'])]
df.region.nunique()
# Out:
# 52

# %%
len(df['region'].unique())
# Out:
# 52

# %%
df.region.unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'WestTexNewMexico'], dtype=object)

# %%
df_region_price_volume = df.groupby(['region'])['AveragePrice'].mean().to_frame()
df_region_price_volume['Total Volume']= df.groupby(['region'])['Total Volume'].sum()
df_region_price_volume.reset_index(inplace=True)
df_region_price_volume.head()
# Out:
#                 region  AveragePrice  Total Volume
# 0               Albany      1.561036  1.606780e+07
# 1              Atlanta      1.337959  8.860512e+07
# 2  BaltimoreWashington      1.534231  1.347139e+08
# 3                Boise      1.348136  1.441319e+07
# 4               Boston      1.530888  9.727398e+07

# %%
df_new=df.groupby(['region','year','type']).agg({'AveragePrice':'mean','Total Volume':'sum'})
df_new.head()
# Out:
#                           AveragePrice  Total Volume
# region year type
# Albany 2015 conventional      1.171923    3962854.18
#             organic           1.905577      67042.25
#        2016 conventional      1.345769    5171564.06
#             organic           1.722115      92771.53
#        2017 conventional      1.526415    5076262.79

# %%
group_df.columns
# Out:
# Index(['region', 'year', 0], dtype='object')

# %%
group_df = df.groupby(['region','year']).size().reset_index()
# group_df.columns = 
group_df.nlargest(1,0)
# Out:
#    region  year    0
# 2  Albany  2017  106

# %%
df_new.keys()
# Out:
# Index(['AveragePrice', 'Total Volume'], dtype='object')

# %%
df_region_price_volume.columns
# Out:
# Index(['region', 'AveragePrice', 'Total Volume'], dtype='object')

# %%
ax= df_region_price_volume.plot.bar(x ='region',y='AveragePrice',figsize=(22,15))
ax.set_xlabel(" USA city or region")
ax.set_ylabel("Avocado Average Price")
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
ax1= df_region_price_volume.plot.scatter('Total Volume','AveragePrice',figsize=(15,15))

# %%
df_region_price_volume.describe()
# Out:
#        AveragePrice  Total Volume
# count     54.000000  5.400000e+01
# mean       1.405955  2.874704e+08
# std        0.166653  8.176668e+08
# min        1.047929  1.094267e+07
# 25%        1.287848  3.556968e+07
# 50%        1.400725  7.168585e+07
# 75%        1.515947  1.828629e+08
# max        1.818639  5.864740e+09

# %%
df_region_price_volume.sort_values(by=['Total Volume'],ascending=False)
# Out:
#                  region  AveragePrice  Total Volume
# 51              TotalUS      1.319024  5.864740e+09
# 52                 West      1.272219  1.086779e+09
# 6            California      1.395325  1.028982e+09
# 45         SouthCentral      1.101243  1.011280e+09
# 29            Northeast      1.601923  7.132809e+08
# 46            Southeast      1.398018  6.152384e+08
# 15           GreatLakes      1.338550  5.896425e+08
# 25             Midsouth      1.404763  5.083494e+08
# 22           LosAngeles      1.216006  5.078965e+08
# 35               Plains      1.436509  3.111885e+08
# 28              NewYork      1.727574  2.407341e+08
# 11        DallasFtWorth      1.085592  2.084193e+08
# 18              Houston      1.047929  2.031679e+08
# 33        PhoenixTucson      1.224438  1.956433e+08
# 53     WestTexNewMexico      1.261701  1.445218e+08
# 12               Denver      1.218580  1.389025e+08
# 42         SanFrancisco      1.804201  1.358302e+08
# 2   BaltimoreWashington      1.534231  1.347139e+08
# 8               Chicago      1.556775  1.337023e+08
# 36             Portland      1.317722  1.105522e+08
# 43              Seattle      1.442574  1.092142e+08
# 24    MiamiFtLauderdale      1.428491  9.767322e+07
# 4                Boston      1.530888  9.727398e+07
# 41             SanDiego      1.398166  8.979192e+07
# 1               Atlanta      1.337959  8.860512e+07
# 40           Sacramento      1.621568  7.516375e+07
# 32         Philadelphia      1.632130  7.183880e+07
# 30   NorthernNewEngland      1.477396  7.153289e+07
# 50                Tampa      1.408846  6.600454e+07
# 13              Detroit      1.276095  6.342242e+07
# 44        SouthCarolina      1.403284  6.075377e+07
# 31              Orlando      1.506213  5.866070e+07
# 21             LasVegas      1.380917  5.437691e+07
# 17  HartfordSpringfield      1.818639  5.067054e+07
# 37    RaleighGreensboro      1.555118  4.820273e+07
# 27     NewOrleansMobile      1.304793  4.569514e+07
# 9      CincinnatiDayton      1.209201  4.452201e+07
# 38      RichmondNorfolk      1.291331  4.223085e+07
# 16   HarrisburgScranton      1.513284  4.180886e+07
# 26            Nashville      1.212101  3.561209e+07
# 7             Charlotte      1.606036  3.555554e+07
# 48              StLouis      1.430621  3.207283e+07
# 19         Indianapolis      1.313994  3.026339e+07
# 14          GrandRapids      1.505000  3.021174e+07
# 10             Columbus      1.252781  2.999336e+07
# 20         Jacksonville      1.510947  2.879000e+07
# 39              Roanoke      1.247929  2.504201e+07
# 5      BuffaloRochester      1.516834  2.296247e+07
# 34           Pittsburgh      1.364320  1.880635e+07
# 23           Louisville      1.286686  1.609700e+07
# 0                Albany      1.561036  1.606780e+07
# 47              Spokane      1.445592  1.556528e+07
# 3                 Boise      1.348136  1.441319e+07
# 49             Syracuse      1.520325  1.094267e+07

# %%
df.groupby(['region','type']).agg({'AveragePrice':'mean'})
# Out:
#                                   AveragePrice
# region              type
# Albany              conventional      1.348757
#                     organic           1.773314
# Atlanta             conventional      1.068817
#                     organic           1.607101
# BaltimoreWashington conventional      1.344201
#                     organic           1.724260
# Boise               conventional      1.076036
#                     organic           1.620237
# Boston              conventional      1.304379
#                     organic           1.757396
# BuffaloRochester    conventional      1.382308
#                     organic           1.651361
# California          conventional      1.105444
#                     organic           1.685207
# Charlotte           conventional      1.275089
#                     organic           1.936982
# Chicago             conventional      1.369349
#                     organic           1.744201
# CincinnatiDayton    conventional      1.015503
#                     organic           1.402899
# Columbus            conventional      1.066272
#                     organic           1.439290
# DallasFtWorth       conventional      0.846450
#                     organic           1.324734
# Denver              conventional      1.073964
#                     organic           1.363195
# Detroit             conventional      1.123964
#                     organic           1.428225
# GrandRapids         conventional      1.325030
#                     organic           1.684970
# ...                                        ...
# RaleighGreensboro   conventional      1.227101
#                     organic           1.883136
# RichmondNorfolk     conventional      1.119822
#                     organic           1.462840
# Roanoke             conventional      1.096036
#                     organic           1.399822
# Sacramento          conventional      1.273964
#                     organic           1.969172
# SanDiego            conventional      1.061479
#                     organic           1.734852
# SanFrancisco        conventional      1.397160
#                     organic           2.211243
# Seattle             conventional      1.169763
#                     organic           1.715385
# SouthCarolina       conventional      1.146213
#                     organic           1.660355
# SouthCentral        conventional      0.869408
#                     organic           1.333077
# Southeast           conventional      1.163018
#                     organic           1.633018
# Spokane             conventional      1.115976
#                     organic           1.775207
# StLouis             conventional      1.185740
#                     organic           1.675503
# Syracuse            conventional      1.386923
#                     organic           1.653728
# Tampa               conventional      1.201598
#                     organic           1.616095
# WestTexNewMexico    conventional      0.842130
#                     organic           1.688855
#
# [104 rows x 1 columns]

# %%
df_org_conven=df.groupby(['region','type']).agg({'AveragePrice':'mean'})
df_org_conven.head()
# Out:
#                                   AveragePrice
# region              type
# Albany              conventional      1.348757
#                     organic           1.773314
# Atlanta             conventional      1.068817
#                     organic           1.607101
# BaltimoreWashington conventional      1.344201

# %%
df_org_conven.iloc(2,['region')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-214-abe63e48d366> in <module>()
# ----> 1 df_org_conven.iloc(2,['region', 'type'])
#
# TypeError: __call__() takes from 1 to 2 positional arguments but 3 were given

# %%
plt.figure(figsize=(7,5))
data.Height.plot.hist(bins = 20, normed=True, label = 'Normalized histogram', alpha = 0.7)
# plot the calculated curve
plt.plot(pdfx, pdfy, label = 'Density function')
plt.ylabel ('Probabilities')
plt.legend()
plt.title ('Conventional avocados average price')
plt.show()
